# %% [markdown]
# Análise da projeção do consumo dos items da cesta básica baseando-se na tabela Projeção da População do IBGE
#
# Tabela 7365 - Proporção de pessoas, por grupo de idade - https://sidra.ibge.gov.br/tabela/7365

# %%
import pandas as pd
import plotly.express as px

# %%
projecao_pop = pd.read_excel('C:\dcc-fellowship-ciencia-de-dados\projecao_populacao.xlsx')

# %%
projecao_pop.head()
# Out:
#     Ano    Região  Populacao
# 0  2018    Brasil  208494900
# 1  2018     Norte   18182253
# 2  2018  Nordeste   56760780
# 3  2018   Sudeste   87711946
# 4  2018       Sul   29754036

# %%
consumo_regiao = pd.read_excel('C:\dcc-fellowship-ciencia-de-dados\pof_rendimento_regiao_2_copia.xlsx')

# %%
consumo_regiao
# Out:
#                   Items        Região  Classe F  Classe E  Classe D  Classe C  \
# 0          Arroz polido        Brasil     20.48     20.28     18.80     14.86
# 1          Arroz polido         Norte     17.84     19.64     16.94     18.65
# 2          Arroz polido      Nordeste     22.35     22.21     19.58     14.12
# 3          Arroz polido       Sudeste     18.96     16.81     18.67     14.60
# 4          Arroz polido           Sul     15.58     19.33     15.77     12.16
# 5          Arroz polido  Centro-Oeste     27.03     32.29     24.80     21.73
# 6                Feijão        Brasil      5.69      5.80      5.25      4.70
# 7                Feijão         Norte      3.78      4.12      4.50      3.70
# 8                Feijão      Nordeste      6.65      7.45      6.96      6.69
# 9                Feijão       Sudeste      5.65      4.92      5.05      4.82
# 10               Feijão           Sul      4.30      4.67      3.90      3.11
# ...

# %%
projecao_consumo_regiao = pd.merge(projecao_pop, consumo_regiao, how = 'inner', on = 'Região')

# %%
projecao_consumo_regiao.head()
# Out:
#     Ano  Região  Populacao                Items  Classe F  Classe E  Classe D  \
# 0  2018  Brasil  208494900         Arroz polido     20.48     20.28     18.80
# 1  2018  Brasil  208494900               Feijão      5.69      5.80      5.25
# 2  2018  Brasil  208494900  Farinha de mandioca      3.83      3.09      1.86
# 3  2018  Brasil  208494900     Farinha de trigo      1.43      1.90      2.62
# 4  2018  Brasil  208494900        Fubá de milho      2.16      1.45      1.09
#
#    Classe C  Classe B  Classe A  Consumo médio
# 0     14.86     15.57     12.40      17.065000
# 1      4.70      4.75      3.71       4.983333
# 2      1.39      0.99      1.02       2.030000
# 3      2.56      2.82      2.54       2.311667
# 4      0.83      0.67      0.52       1.120000

# %%
projecao_consumo_regiao.to_excel('projecao_consumo_regiao.xlsx')

# %% [markdown]
# Projeção da demanda populacional por item da cesta básica considerando a média de consumo por clase

# %%
projecao_demanda_brasil = pd.read_excel("C:\dcc-fellowship-ciencia-de-dados\projecao_demanda_brasil.xlsx")
projecao_demanda_brasil
# Out:
#       Ano  Região  Populacao (mi)                Items  \
# 0    2018  Brasil       208494900         Arroz polido
# 1    2018  Brasil       208494900               Feijão
# 2    2018  Brasil       208494900  Farinha de mandioca
# 3    2018  Brasil       208494900     Farinha de trigo
# 4    2018  Brasil       208494900        Fubá de milho
# ..    ...     ...             ...                  ...
# 112  2030  Brasil       224868462        Fubá de milho
# 113  2030  Brasil       224868462       Açúcar cristal
# 114  2030  Brasil       224868462      Molho de tomate
# 115  2030  Brasil       224868462         Óleo de soja
# 116  2030  Brasil       224868462           Café moído
#
#      Consumo médio per capita (kg)  Demanda pop (ton)
# 0                        17.065000       3.557965e+06
# 1                         4.983333       1.039000e+06
# 2                         2.030000       4.232446e+05
# 3                         2.311667       4.819707e+05
# ...

# %% [markdown]
# Criando um dataframe para cada item

# %%
df_arroz=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Arroz ']
df_cafe=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Café (em grão)']
df_cana=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Cana-de-açúcar']
df_feijao=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Feijão (em grão)']
df_mandioca=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Mandioca']
df_milho=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Milho (em grão)']
df_soja=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Soja (em grão)']
df_tomate=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Tomate']
df_trigo=projecao_demanda_brasil[projecao_demanda_brasil['Items']=='Trigo (em grão)']

# %%
projecao_consumo_demanda_regiao.head()
# Out:
#    Unnamed: 0   Ano                 Item  Região  Proj. Populacao  \
# 0           0  2018         Arroz polido  Brasil        208494900
# 1           1  2018     Feijão-mulatinho  Brasil        208494900
# 2           2  2018         Feijão-preto  Brasil        208494900
# 3           3  2018  Farinha de mandioca  Brasil        208494900
# 4           4  2018     Farinha de trigo  Brasil        208494900
#
#    Consumo per capita (kg/ano)  Demanda (ton/ano)
# 0                        20.48         4269975.552
# 1                         0.89          185560.461
# 2                         1.09          227259.441
# 3                         3.83          798535.467
# 4                         1.43          298147.707

# %%
projecao_consumo_demanda_regiao.to_excel('projecao_consumo_demanda_regiao.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\dcc-fellowship-ciencia-de-dados\projecao_consumo.ipynb Célula: 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/dcc-fellowship-ciencia-de-dados/projecao_consumo.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> projecao_consumo_demanda_regiao.to_excel('projecao_consumo_demanda_regiao.xlsx')
#
# File c:\Users\nield\anaconda3\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
# ...

# %% [markdown]
# Projeção de consumo para cada região

# %%
projecao_consumo_demanda_nordeste = projecao_consumo_demanda_regiao.query("Região == 'Nordeste'")

# %%
fig = px.line(projecao_consumo_demanda_nordeste, x = 'Ano', y = 'Demanda (ton/ano) ', color='Item', title = 'Demanda de alimentos por classe na regiao NORDESTE', labels= {'Items': 'Alimentos', 'value': 'Consumo anual per capita (kg)' })
fig.show()
